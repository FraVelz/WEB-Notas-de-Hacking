# %% [markdown]
# # Hola que tal :)

# %%
print("hola mundo")
# Out:
# La ejecución de celdas con 'Python 3.13.7' requiere el paquete ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crear un entorno de Python</a> con los paquetes necesarios.
#
# O instale "ipykernel" mediante el comando: "/usr/bin/python -m pip install ipykernel -U --user --force-reinstall"
